# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url, sep='\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))
chipo_filtered = chipo.drop_duplicates(['item_name', 'quantity', 'choice_description'])
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
price_over_10 = chipo_one_prod[chipo_one_prod['item_price'] > 10].item_name.nunique()
print(f"Products costing more than $10.00: {price_over_10}")
# Out:
# Products costing more than $10.00: 25

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
price_per_item = chipo_one_prod[['item_name', 'choice_description', 'item_price']]
print("\nPrice of each item (first 5):")
print(price_per_item.head())
# Out:
# Price of each item (first 5):
#                                item_name  \
# 0           Chips and Fresh Tomato Salsa
# 1                                   Izze
# 2                       Nantucket Nectar
# 3  Chips and Tomatillo-Green Chili Salsa
# 5                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
sorted_chipo = chipo.sort_values(by='item_name')

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
most_expensive_qty = chipo.sort_values(by="item_price", ascending=False).head(1)['quantity'].values[0]
print(f"\nQuantity of the most expensive item: {most_expensive_qty}")
# Out:
# Quantity of the most expensive item: 15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
veggie_salad_count = len(chipo[chipo.item_name == "Veggie Salad Bowl"])
print(f"Veggie Salad Bowl ordered: {veggie_salad_count} times")
# Out:
# Veggie Salad Bowl ordered: 18 times

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
canned_soda_multi = len(chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)])
print(f"Orders with more than one Canned Soda: {canned_soda_multi}")
# Out:
# Orders with more than one Canned Soda: 20
